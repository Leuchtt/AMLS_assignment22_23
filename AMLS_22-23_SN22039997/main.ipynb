# %%
import import_ipynb
import A1.Logistic_regression
# Out:
# importing Jupyter notebook from D:\AMLS_22-23_SN12345678\A1\Logistic_regression.ipynb
# Dataset prepared
# Accuracy on test set: 0.91
#               precision    recall  f1-score   support
#
#            0       0.91      0.91      0.91       500
#            1       0.91      0.91      0.91       500
#
#     accuracy                           0.91      1000
#    macro avg       0.91      0.91      0.91      1000
# weighted avg       0.91      0.91      0.91      1000

# %%
import A1.CNN
# Out:
# importing Jupyter notebook from D:\AMLS_22-23_SN12345678\A1\CNN.ipynb
# Dataset prepared
# Dataset loaded
# Model completed
# Testing
# ...
# Accuracy on test set: 0.96
#               precision    recall  f1-score   support
#
#            0       0.97      0.95      0.96       500
#            1       0.95      0.97      0.96       500
#
#     accuracy                           0.96      1000
#    macro avg       0.96      0.96      0.96      1000
# weighted avg       0.96      0.96      0.96      1000

# %%
import A2.Logistic_regression
# Out:
# importing Jupyter notebook from D:\AMLS_22-23_SN12345678\A2\Logistic_regression.ipynb
# Dataset prepared
# Accuracy on test set: 0.879
#               precision    recall  f1-score   support
#
#            0       0.89      0.86      0.88       500
#            1       0.87      0.89      0.88       500
#
#     accuracy                           0.88      1000
#    macro avg       0.88      0.88      0.88      1000
# weighted avg       0.88      0.88      0.88      1000

# %%
import A2.SVM
# Out:
# importing Jupyter notebook from D:\AMLS_22-23_SN12345678\A2\SVM.ipynb
# Dataset prepared
# Accuracy Score on test data:  0.877
#               precision    recall  f1-score   support
#
#            0       0.87      0.89      0.88       500
#            1       0.89      0.86      0.88       500
#
#     accuracy                           0.88      1000
#    macro avg       0.88      0.88      0.88      1000
# weighted avg       0.88      0.88      0.88      1000

# %%
import B1.decision_tree
# Out:
# importing Jupyter notebook from D:\AMLS_22-23_SN12345678\B1\decision_tree.ipynb
# Dataset prepared
# Accuracy Score on test data:  0.9988
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       500
#            1       1.00      1.00      1.00       500
#            2       1.00      1.00      1.00       500
#            3       1.00      1.00      1.00       500
#            4       1.00      1.00      1.00       500
#
#     accuracy                           1.00      2500
#    macro avg       1.00      1.00      1.00      2500
# weighted avg       1.00      1.00      1.00      2500

# %%
import B1.random_forest
# Out:
# importing Jupyter notebook from D:\AMLS_22-23_SN12345678\B1\random_forest.ipynb
# Dataset prepared
# Random Forest test Accuracy: 1.0
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       500
#            1       1.00      1.00      1.00       500
#            2       1.00      1.00      1.00       500
#            3       1.00      1.00      1.00       500
#            4       1.00      1.00      1.00       500
#
#     accuracy                           1.00      2500
#    macro avg       1.00      1.00      1.00      2500
# weighted avg       1.00      1.00      1.00      2500

# %%
#B2 data preprocessing
import B2.sunglass_remove
# Out:
# importing Jupyter notebook from D:\AMLS_22-23_SN12345678\B2\sunglass_remove.ipynb
# Sunglasses classification completed
# train_new.csv saved
# test_new.csv saved

# %%
import B2.decision_tree
# Out:
# importing Jupyter notebook from D:\AMLS_22-23_SN12345678\B2\decision_tree.ipynb
# Dataset prepared
# Accuracy Score on test data:  0.9676344597810567
#               precision    recall  f1-score   support
#
#            0       0.98      0.96      0.97       419
#            1       0.97      0.97      0.97       406
#            2       0.97      0.96      0.97       448
#            3       0.95      0.97      0.96       426
#            4       0.97      0.97      0.97       402
#
#     accuracy                           0.97      2101
#    macro avg       0.97      0.97      0.97      2101
# weighted avg       0.97      0.97      0.97      2101

# %%
import B2.random_forest
# Out:
# importing Jupyter notebook from D:\AMLS_22-23_SN12345678\B2\random_forest.ipynb
# Dataset prepared
# Random Forest test Accuracy: 0.9566872917658258
#               precision    recall  f1-score   support
#
#            0       0.93      0.95      0.94       419
#            1       0.94      0.95      0.94       406
#            2       0.99      0.95      0.97       448
#            3       0.95      0.96      0.96       426
#            4       0.98      0.97      0.98       402
#
#     accuracy                           0.96      2101
#    macro avg       0.96      0.96      0.96      2101
# weighted avg       0.96      0.96      0.96      2101
